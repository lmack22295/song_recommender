# %%
# !pip install lyricsgenius

# %%
import lyricsgenius as genius

# %%
GENIUS_API_KEY = '2qq1ZZDwqUbHXCm7p9QFyhK7ZNKgslA8EgWf7BUonfz5PKPSPHtJ0ISVj3nyeHat'
api = genius.Genius(GENIUS_API_KEY, verbose=False)

# %%
        try:
            song = api.search_song('Self Control', artist='Frank Ocean')
            song_album = song.album
            song_album_url = song.album_url
            featured_artists = song.featured_artists
            song_lyrics = re.sub("\n", " ", song.lyrics)
            song_media = song.media
            song_url = song.url
            song_writer_artists = song.writer_artists
            song_year = song.year
        except:
            song_album = "null"
            song_album_url = "null"
            featured_artists = "null"
            song_lyrics = "null"
            song_media = "null"
            song_url = "null"
            song_writer_artists = "null"
            song_year = "null"

# %%
api.search_artist?

# %%
api.search_artist("Andy Shauf", max_songs=3, sort="title")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-93abb1c220df> in <module>
# ----> 1 api.search_artist("Andy Shauf", max_songs=3, sort="title")
#
# ~/analyzing_music/env3/lib/python3.6/site-packages/lyricsgenius/api.py in search_artist(self, artist_name, max_songs, sort, per_page, get_full_info, allow_name_change, artist_id)
#     319
#     320         artist_info = self.get_artist(artist_id)
# --> 321         found_name = artist_info['artist']['name']
#     322         if found_name != artist_name and allow_name_change:
#     323             if self.verbose:
#
# TypeError: 'NoneType' object is not subscriptable

# %%
song = api.search_song('Self Control', artist='Frank Ocean')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-2b1dd825ea90> in <module>
# ----> 1 song = api.search_song('Self Control', artist='Frank Ocean')
#
# ~/analyzing_music/env3/lib/python3.6/site-packages/lyricsgenius/api.py in search_song(self, title, artist, get_full_info)
#     265         song_info = result.copy()
#     266         if get_full_info:
# --> 267             song_info.update(self.get_song(result['id'])['song'])
#     268         lyrics = self._scrape_song_lyrics_from_url(song_info['url'])
#     269
#
# TypeError: 'NoneType' object is not subscriptable

# %%
import pandas as pd

df = pd.read_csv("all_genius_artist_genres.csv")
len(df.artist.unique())
# Out:
# 10137

# %%
import numpy as np

# %%
list(df.artist.unique())
# Out:
# ["Yung Nigo Drippin'",
#  'Yung Nnelg',
#  'Yung Nugget',
#  'Yung Ouzo',
#  'Yung Pinch',
#  'Yung Ralph',
#  'Yung Sarria',
#  'Yung Scuff',
#  'Yung Sherman',
#  'Yung Simmie',
#  'Yung Swiss',
#  'Yung Titties',
#  'Yung Tory',
#  'Yunk Vino',
#  'YUN MUFASA',
#  'Yuno',
#  'Yura Yunita',
#  'Yuri',
#  'Yuridia',
#  'Yuyoyuppe',
#  'Yuzmv',
#  'Yves Duteil',
#  'Yves Montand',
#  'Yves Simon',
#  'Yves Tumor',
#  'Yves V',
#  'Yvette Young',
#  'Yvncc',
#  'YVNG CIRIUS',
#  'YvngCrow',
#  'Yvonne Catterfeld',
#  'Yvonne Chaka Chaka',
#  'Yvonne Elliman',
#  'Yvonne Fair',
#  'Yxng Bane',
#  'Yzomandias',
#  'Zac Brown Band',
#  'Zac Efron',
#  'Zach Callison',
#  'Elliot Root',
#  'Elliott Smith',
#  'Elliott Trent',
#  'Elliphant',
#  'Ellips',
#  'El Matador',
#  'Elmo & Patsy',
#  'Elmore James',
#  'Elodie',
#  'Elohim',
#  'Eloy',
#  'El-P',
#  'El Pibe',
#  'El Profesor',
#  'El Rass',
#  'Elsa & Emilie',
#  'Elsa y Elmar',
#  'El Tigrillo Palma',
#  'El Tri',
#  'Elujay',
# ...

# %%
import pickle

# %%
ls artist_to_popular_songs/
# Out:
# artist_to_popular_songs.pkl      artist_to_popular_songs_24.pkl
# artist_to_popular_songs_0.pkl    artist_to_popular_songs_25.pkl
# artist_to_popular_songs_1.pkl    artist_to_popular_songs_26.pkl
# artist_to_popular_songs_10.pkl   artist_to_popular_songs_27.pkl
# artist_to_popular_songs_100.pkl  artist_to_popular_songs_28.pkl
# artist_to_popular_songs_101.pkl  artist_to_popular_songs_29.pkl
# artist_to_popular_songs_102.pkl  artist_to_popular_songs_3.pkl
# artist_to_popular_songs_103.pkl  artist_to_popular_songs_30.pkl
# artist_to_popular_songs_104.pkl  artist_to_popular_songs_31.pkl
# artist_to_popular_songs_105.pkl  artist_to_popular_songs_32.pkl
# artist_to_popular_songs_106.pkl  artist_to_popular_songs_33.pkl
# artist_to_popular_songs_107.pkl  artist_to_popular_songs_34.pkl
# artist_to_popular_songs_108.pkl  artist_to_popular_songs_35.pkl
# artist_to_popular_songs_109.pkl  artist_to_popular_songs_36.pkl
# artist_to_popular_songs_11.pkl   artist_to_popular_songs_37.pkl
# ...
